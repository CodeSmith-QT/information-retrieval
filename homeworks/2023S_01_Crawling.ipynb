# %% [markdown]
# # 1. Crawler
#
# ## 1.0. Related example
#
# This code shows `wget`-like tool written in python. Run it from console (`python wget.py`), make it work. Check the code, reuse, and modify for your needs.

# %%
import argparse
import os
import re
import requests


def wget(url):
    """
      Function for requesting urls
      args:
        The URL to be requested
      response:
        The content of the response
    """
    def handleLoadToVar(resp):
      """
        Function for chunking the http response in order to manage system resources
        args:
          resp: The http response
        response:
          The chunked response
      """
      result = bytearray()
      resp.raise_for_status()      
      for chunk in resp.iter_content(chunk_size=8192): 
        result += chunk
      return result
    
    # allow redirects - in case file is relocated
    resp = requests.get(url, allow_redirects=True, stream = True)
    # this can also be 2xx, but for simplicity now we stick to 200
    # you can also check for `resp.ok`
    if resp.status_code != 200:
        print(resp.status_code, resp.reason, 'for', url)
        return
    
    # just to be cool and print something
    print(*[f"{key}: {value}" for key, value in resp.headers.items()], sep='\n')
    print()
    
    return handleLoadToVar(resp)

# %% [markdown]
# ### 1.0.1. How to parse a page?
#
# If you build a crawler, you might follow one of the approaches:
# 1. search for URLs in the page, assuming this is just a text.
# 2. search for URLs in the places where URLs should appear: `<a href=..`, `<img src=...`, `<iframe src=...` and so on.
#
# To follow the first approach you can rely on some good regular expression. [Like this](https://stackoverflow.com/a/3809435).
#
# To follow the second approach just read one of these: [short answer](https://stackoverflow.com/questions/1080411/retrieve-links-from-web-page-using-python-and-beautifulsoup) or [exhaustive explanation](https://hackersandslackers.com/scraping-urls-with-beautifulsoup/).

# %% [markdown]
# ## 1.1. [15] Download and persist #
# Please complete a code for `load()`, `download()` and `persist()` methods of `Document` class. What they do:
# - for a given URL `download()` method downloads binary data and stores in `self.content`. It returns `True` for success, else `False`.
# - `persist()` method saves `self.content` somewhere in file system. We do it to avoid multiple downloads (for caching in other words).
# - `load()` method loads data from hard drive. Returns `True` for success.
#
# Tests checks that your code somehow works.
#
# **NB Passing the test doesn't mean you correctly completed the task.** These are **criteria, which have to be fullfilled**:
# 1. URL is a unique identifier (as it is a subset of URI). Thus, documents with different URLs should be stored in different files. Typical errors: documents from the same domain are overwritten to the same file, URLs with similar endings are downloaded to the same file, etc.
# 2. The document can be not only a text file, but also a binary. Pay attention that if you download `mp3` file, it still can be played. Hint: don't hurry to convert everything to text.

# %%
import requests
from urllib.parse import quote
import hashlib

class Document:
    
    def __init__(self, url):
        self.url = url
        
    def get(self):
        if not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
    
    def download(self):      
        #TODO download self.url content, store it in self.content and return True in case of success
        try:  
          result = wget(self.url)  
          if(result is None):
            return False
          self.content = result
          return True
        except:
          return False
    
    def persist(self):
        #We use the hash of the url to save the file
        filename = hashlib.sha256(self.url.encode()).hexdigest()
        with open(filename, "wb") as file:
          file.write(self.content)
            
    def load(self):  
        #TODO load content from hard drive, store it in self.content and return True in case of success    
        try:
          filename = hashlib.sha256(self.url.encode()).hexdigest()
          with open(filename, "rb") as file:
            self.content = file.read()
          return True
        except:
          return False

# %% [markdown]
# ### 1.1.1. Tests ###

# %%
doc = Document('http://sprotasov.ru/data/iu.txt')

doc.get()
assert doc.content, "Document download failed"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document content error"

doc.get()
assert doc.load(), "Load should return true for saved document"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document load from disk error"
# Out:
# X-Powered-By: Express
# Accept-Ranges: bytes
# Cache-Control: public, max-age=0
# Last-Modified: Mon, 23 Apr 2018 08:15:13 GMT
# ETag: W/"17eb-162f1923268"
# Content-Type: text/plain; charset=UTF-8
# Content-Length: 6123
# Date: Sun, 12 Feb 2023 09:51:53 GMT
# Connection: keep-alive

# %% [markdown]
# ## 1.2. [10] Parse HTML
# `BeautifulSoap` library is a de facto standard to parse XML and HTML documents in python. Use it to complete `parse()` method that extracts document contents. You should initialize:
# 1. `self.anchors` list of tuples `('text', 'url')` met in a document. Be aware, there exist relative links (e.g. `../content/pic.jpg`). Use `urllib.parse.urljoin()` to fix this issue.
# 2. `self.images` list of images met in a document. Again, links can be relative to current page.
# 3. `self.text` should keep plain text of the document without scripts, tags, comments and so on. You can refer to [this stackoverflow answer](https://stackoverflow.com/a/1983219) for details.
#
# **NB All these 3 criteria must be fulfilled to get full point for the task.**

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
import re

class HtmlDocument(Document):
    #TODO extract plain text, images and links from the document    

    def parse(self):
        def _preprocess_link(link):
          """
            Function for handling relative urls
            args:
              link: The urls to be processed
            response:
              The processed urls
          """
          if re.match("(?:^[a-z][a-z0-9+\.-]*:|\/\/)",link ):
            return link
          else:
            return urllib.parse.urljoin(self.url,link)

        def _get_anchors(dom):
          """
            Function for getting the urls and the corresponding tags in the dom
            args:
              dom: The dom 
            response:
              A list of all anchor links and names              
          """
          all_hrefs = dom.find_all('a', href=True)
          all_urls = set()
          return list(set((a.text,_preprocess_link(a['href'])) for a in all_hrefs))
        
        def _get_images(dom):
          """
            Function for getting the urls and the corresponding tags in the dom
            args:
              dom: The dom 
            response:
              A list of all the image sources              
          """          
          all_images= dom.find_all('img', src=True)
          all_src = set()          
          return list(set([_preprocess_link(img['src']) for img in all_images]))                  
        
        def tag_visible(element):
          """
            Function for checking if a html element is among the visible elements in the dom
            args:
              element: The HTML element to be checked
            response: A boolean specifying if an element is visible                                            
          """
          if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
              return False
          if isinstance(element, Comment):
              return False
          return True
        
        def _get_text(dom):
          """
            Function for getting visible texts in the dom
            args:
              dom: The dom 
            response: A string of all the visible texts             
          """
          texts = dom.findAll(text=True)
          visible_texts = filter(tag_visible, texts)
          return u" ".join(t.strip() for t in visible_texts)
        
        try:
          dom = BeautifulSoup(self.content.decode())  
          self.anchors = _get_anchors(dom)
          self.images = _get_images(dom)
          self.text = _get_text(dom)
        except Exception as e:
          print(e)
          pass

# %% [markdown]
# ### 1.2.1. Tests

# %%
doc = HtmlDocument("http://sprotasov.ru")
doc.get()
doc.parse()

assert "just few links" in doc.text, "Error parsing text"
assert "http://sprotasov.ru/images/gb.svg" in doc.images, "Error parsing images"
assert any(p[1] == "https://twitter.com/07C3" for p in doc.anchors), "Error parsing links"
# Out:
# X-Powered-By: Express
# Accept-Ranges: bytes
# Cache-Control: public, max-age=0
# Last-Modified: Wed, 13 Apr 2022 14:34:29 GMT
# ETag: W/"146f-1802358e108"
# Content-Type: text/html; charset=UTF-8
# Content-Length: 5231
# Date: Sun, 12 Feb 2023 09:51:53 GMT
# Connection: keep-alive

# %% [markdown]
# ## 1.3. [10] Document analysis ##
# Complete the code for `HtmlDocumentTextData` class. Implement word and sentence splitting (use any method you can propose).
#
# **Criteria to succeed in the task**:
# 1. Your `get_word_stats()` method should return `Counter` object.
# 2. Don't forget to lowercase your words for counting.
# 3. Sentences should be obtained from inside `<body>` tag only.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from collections import Counter
from nltk import tokenize

class HtmlDocumentTextData:
    
    def __init__(self, url):
        self.doc = HtmlDocument(url)
        try:
          self.doc.get()
          self.doc.parse()
        except FileNotFoundError:
          print("File Not Found")
    
    def get_sentences(self):
        #TODO implement sentence parser
        result = nltk.sent_tokenize(self.doc.text.strip())
        return result
    
    def get_word_stats(self):
        result = nltk.word_tokenize(self.doc.text.strip())
        #TODO return Counter object of the document, containing mapping {`word` -> count_in_doc}
        return Counter(map(str.lower,result))

# %% [markdown]
# ### 1.3.1. Tests ###

# %%
doc = HtmlDocumentTextData("https://innopolis.university/")
print(doc.get_word_stats().most_common(10))
assert [x for x in doc.get_word_stats().most_common(10) if x[0] == 'иннополис'], 'иннополис should be among most common'
# Out:
# Server: nginx/1.22.0
# Date: Sun, 12 Feb 2023 09:51:57 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# X-Powered-By: PHP/7.4.28
# Expires: Fri, 07 Jun 1974 04:00:00 GMT
# Last-Modified: Sun, 12 Feb 2023 09:19:02 GMT
# X-Bitrix-Composite: Cache (200)
# X-Content-Type-Options: nosniff
# X-Frame-Options: SAMEORIGIN
# Referrer-Policy: strict-origin-when-cross-origin
# Strict-Transport-Security: max-age=15768000
# Set-Cookie: SESSID=bbce; path=/; Secure; HttpOnly
# Content-Encoding: gzip
#
# [('и', 44), (',', 43), ('в', 22), ('иннополис', 20), ('.', 19), ('с', 13), ('на', 12), ('университет', 11), ('университета', 11), ('центр', 10)]

# %% [markdown]
# ## 1.4. [15] Crawling ##
#
# Method `crawl_generator()` is given starting url (`source`) and max depth of search. It should return a **generator** of `HtmlDocumentTextData` objects (return a document as soon as it is downloaded and parsed). You can benefit from `yield obj_name` python construction. Use `HtmlDocumentTextData.anchors` field to go deeper.

# %%
from queue import Queue

class Crawler:
    
    def crawl_generator(self, source, depth=1):
      #f we are required to process a file once, 
      #we can add a set for tracking the urls but
      # since it wasn't a requirement, we skip that
        q = Queue()
        q.put((source,0))      
        while True:
          try:
              url, index = q.get_nowait()
              doc = HtmlDocumentTextData(url)
              if hasattr(doc.doc, 'anchors') is False:
                continue

              for val, url in doc.doc.anchors:
                if(index+1 <= depth):
                  q.put((url, index+1))
              # map(q.put, list(map(lambda val: (val,index+1), doc.doc.anchors)))
              yield doc
          except Exception as e:
              print(url, e)
              break

# %% [markdown]
# ### 1.4.1. Tests ###

# %%
crawler = Crawler()
counter = Counter()

for c in crawler.crawl_generator("https://innopolis.university/en/", 2):
    if c.doc.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'):
        print("Skipping", c.doc.url)
        continue
    counter.update(c.get_word_stats())
    print(len(counter), "distinct word(s) so far")
    
print("Done")

print(counter.most_common(20))
assert [x for x in counter.most_common(20) if x[0] == 'innopolis'], 'innopolis sould be among most common'
# Out:
# Streaming output truncated to the last 5000 lines.
# 33786 distinct word(s) so far
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:37 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=JF7LxetBM0bT0Qey7qvjFd0M9LYfF4Wi; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:10 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A10; expires=Wed, 07-Feb-2024 10:40:10 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33798 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:38 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:11 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A11; expires=Wed, 07-Feb-2024 10:40:11 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33836 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:39 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=zFGiQ55DU6mI155KaQlE29l1hwNq5HgH; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:11 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A11; expires=Wed, 07-Feb-2024 10:40:11 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33836 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:39 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=1ULq63XYTNsi8l1T4BG533WXBNgaPnIP; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:12 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A12; expires=Wed, 07-Feb-2024 10:40:12 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33898 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:40 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=v0ewmh50usxyjBmW4lLcEcYs7yKGVzfR; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:13 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A13; expires=Wed, 07-Feb-2024 10:40:13 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33900 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:41 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=1eIDivSzAOabaZ6UA7kfR83MFaf4Vqjf; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:13 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A13; expires=Wed, 07-Feb-2024 10:40:13 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33900 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:42 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=B5PeDk21XYpRu7LzaB9V0I0YJWuur4cf; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:14 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A14; expires=Wed, 07-Feb-2024 10:40:14 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33938 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:42 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=MEcQ8XwVRNtnefkMFVCKiwD6S1pgGoy2; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:15 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A15; expires=Wed, 07-Feb-2024 10:40:15 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 33944 distinct word(s) so far
# Server: nginx
# Date: Sun, 12 Feb 2023 10:39:49 GMT
# Content-Type: text/html
# Content-Length: 8947
# Connection: keep-alive
# Keep-Alive: timeout=10
# Last-Modified: Fri, 04 Mar 2022 20:08:27 GMT
# ETag: "622271bb-22f3"
# Expires: Sun, 12 Feb 2023 10:39:48 GMT
# Cache-Control: no-cache
# Accept-Ranges: bytes
# Strict-Transport-Security: max-age=16070400
#
# 33944 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:44 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=QKIL5HCyoigBFt555m1KHdVQCg5Csxsc; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:16 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A16; expires=Wed, 07-Feb-2024 10:40:16 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 34038 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:44 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=GDCzxExx0hn4SD55VIOy5J7TxGFLLx3y; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:17 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A17; expires=Wed, 07-Feb-2024 10:40:17 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Bitrix-Ajax-Status: Authorize
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 34038 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:45 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=Ig9aTt07JBbnBGpn1ZFizTRH5aOWdETL; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:18 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A18; expires=Wed, 07-Feb-2024 10:40:18 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 34061 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:46 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=YfcPaD70LYA1V7PSJ0aMWbDiCbDvWIVY; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A19; expires=Wed, 07-Feb-2024 10:40:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 36789 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:48 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:21 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A21; expires=Wed, 07-Feb-2024 10:40:21 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 36900 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:49 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=TJO9t7t3IKFe17rVZtVBZQlTgSuhDH1c; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:21 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A21; expires=Wed, 07-Feb-2024 10:40:21 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 36919 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:50 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=HBceG4bydJN3c5PaYHTuTEFF5x4CDVtl; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A23; expires=Wed, 07-Feb-2024 10:40:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Bitrix-Ajax-Status: Authorize
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 36919 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:51 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=Br07O0lzxMKT6oBatoFtCYs2xKeHJ4IJ; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A23; expires=Wed, 07-Feb-2024 10:40:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37060 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:52 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:24 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A24; expires=Wed, 07-Feb-2024 10:40:24 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37072 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:52 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=3V8U7p1bw0IF4strsK0J76g8me7XqlB4; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:25 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A25; expires=Wed, 07-Feb-2024 10:40:25 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37099 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:53 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=549y17KXE9CQ32BnqRBmuvFrwbarQAca; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:26 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A26; expires=Wed, 07-Feb-2024 10:40:26 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37113 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:54 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=s4SOcFIrIIZZgNzAnPBPeGmmNvSffME3; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:27 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A27; expires=Wed, 07-Feb-2024 10:40:27 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37126 distinct word(s) so far
# 37126 distinct word(s) so far
# Server: nginx
# Date: Sun, 12 Feb 2023 10:40:01 GMT
# Content-Type: text/html
# Content-Length: 8947
# Connection: keep-alive
# Keep-Alive: timeout=10
# Last-Modified: Fri, 04 Mar 2022 20:08:27 GMT
# ETag: "622271bb-22f3"
# Expires: Sun, 12 Feb 2023 10:40:00 GMT
# Cache-Control: no-cache
# Accept-Ranges: bytes
# Strict-Transport-Security: max-age=16070400
#
# 37126 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:55 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=nIk1bsvEcGBSGxKT4D4oX3vxxjwlZdeK; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:28 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A28; expires=Wed, 07-Feb-2024 10:40:28 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37129 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:56 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=F0ltDHQ2VGFhTaB7khEXNtPyP7cqujaF; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:29 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A29; expires=Wed, 07-Feb-2024 10:40:29 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37151 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:57 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=5oUfqToph2fGwFUaOvnq6Y4FQ6GSVsIW; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:29 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A29; expires=Wed, 07-Feb-2024 10:40:29 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37214 distinct word(s) so far
# 37214 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:58 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:30 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A30; expires=Wed, 07-Feb-2024 10:40:30 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37231 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:39:58 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=5RuIYMap4ZkBN5Gkg3iIWsybJIJT8Cbt; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A31; expires=Wed, 07-Feb-2024 10:40:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37322 distinct word(s) so far
# Server: nginx
# Date: Sun, 12 Feb 2023 10:40:05 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# Last-Modified: Fri, 03 Feb 2023 11:33:59 GMT
# ETag: W/"2a5a-5f3ca0ebf23ce"
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37322 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:40:00 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=wI8KN3GsQP7DdhEmKj3bPF8ywbEUpfFq; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:32 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A32; expires=Wed, 07-Feb-2024 10:40:32 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37351 distinct word(s) so far
# 37351 distinct word(s) so far
# 404 Not Found for https://minobrnauki.gov.ru/open_ministry/gossluzhba/entry/
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:40:01 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=F1FXm8fwqzMLJBchPDdDHrU5pNIblPIF; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:40:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A40%3A34; expires=Wed, 07-Feb-2024 10:40:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37353 distinct word(s) so far
# File Not Found
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:57:46 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 10:58:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2013%3A58%3A19; expires=Wed, 07-Feb-2024 10:58:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37419 distinct word(s) so far
# File Not Found
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:59:57 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=aIs99FCuf543ge4tl98gjFhfGUpVjMip; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:30 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A30; expires=Wed, 07-Feb-2024 11:00:30 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37438 distinct word(s) so far
# 37438 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:59:58 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=FTkKu2kNQyPxLZmrLRHbYe5IhzR02UHO; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A31; expires=Wed, 07-Feb-2024 11:00:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37507 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 10:59:58 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=ArXrnXlqYHavC4LneI8n7R4L3xKn2JG6; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A31; expires=Wed, 07-Feb-2024 11:00:31 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37507 distinct word(s) so far
# Date: Sun, 12 Feb 2023 11:00:05 GMT
# Content-Type: text/html; charset=utf-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Cache-Control: s-maxage=600, stale-while-revalidate
# vary: Accept-Encoding
# x-nextjs-cache: HIT
# x-powered-by: Next.js
# CF-Cache-Status: DYNAMIC
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v3?s=rzJ2aWeuAKE34CDQtjgKSJt7sWoFl1H24%2FVCraVkudkxwsNfFjqXQ4au05dsv%2Feowvpt5omTOaD9dEAQtTBkbKAqSFHhqgGjfiIaDpTXjMIP3Q%2B%2FDv9oWPX8faNuoq4m0WS7TlrT8dyUfYadTd7RARzVOhI55Hi%2BQmID%2Fy%2BIGw%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 7984d18cfc33e3a2-ATL
# Content-Encoding: gzip
# alt-svc: h3=":443"; ma=86400, h3-29=":443"; ma=86400
#
# 37507 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:00 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=cvgfeqvhseJh3VJrFYAgZDS8v9cJ6YxU; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:33 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A33; expires=Wed, 07-Feb-2024 11:00:33 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37556 distinct word(s) so far
# 37556 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:01 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=53zq2nOLPse1m98lo7t1BFGqTEP4m830; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A34; expires=Wed, 07-Feb-2024 11:00:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37598 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:02 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=ecqyqeXJinUA5TO7RkGInllw0Axmzfdi; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A34; expires=Wed, 07-Feb-2024 11:00:34 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37598 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:03 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=UGpjmvZjPo83wdCVqfOX8smarHB7cEYy; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:35 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A35; expires=Wed, 07-Feb-2024 11:00:35 GMT; Max-Age=31103999; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 37621 distinct word(s) so far
# 37621 distinct word(s) so far
# Date: Sun, 12 Feb 2023 11:00:10 GMT
# Content-Type: text/html; charset=utf-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Strict-Transport-Security: max-age=15724800; includeSubDomains
#
# 40162 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:06 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=dAhSUcchlj10Dn1zTPXXzv9uDp8fJ8VZ; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:39 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A39; expires=Wed, 07-Feb-2024 11:00:39 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40190 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:07 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=rTwnAAgcDz753SKPD8YGXrV4unc9z84Q; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:39 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A39; expires=Wed, 07-Feb-2024 11:00:39 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40192 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:00:07 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=Mdf1DxvTXMAAzDVouRUKnhJcAu56cg2x; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:00:40 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A00%3A40; expires=Wed, 07-Feb-2024 11:00:40 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40192 distinct word(s) so far
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:43 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=X96JaV5OvBPGNai1FrAgapaqFmyhDKod; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:16 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A16; expires=Wed, 07-Feb-2024 11:16:16 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40192 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:44 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:17 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A17; expires=Wed, 07-Feb-2024 11:16:17 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40211 distinct word(s) so far
# 40211 distinct word(s) so far
# 40211 distinct word(s) so far
# File Not Found
# 40211 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:45 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:18 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A18; expires=Wed, 07-Feb-2024 11:16:18 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40211 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:46 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=OvB8voD57DySlg00CTTkH7mSOmexPsN5; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A19; expires=Wed, 07-Feb-2024 11:16:19 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40246 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:47 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=srJc25X9O0s0XYIpHhHgW1geh6VW9Onn; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:20 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A20; expires=Wed, 07-Feb-2024 11:16:20 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40264 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:48 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=lxrca5lDcw8RVn6ju5Lxf8O6hA56UpbA; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:21 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A21; expires=Wed, 07-Feb-2024 11:16:21 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40311 distinct word(s) so far
# 40311 distinct word(s) so far
# 40311 distinct word(s) so far
# 40311 distinct word(s) so far
# Server: nginx/1.22.1
# Date: Sun, 12 Feb 2023 11:15:55 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# X-Powered-By: PHP/7.4.22
# Set-Cookie: PHPSESSID=c0q29bfah6of13m5cvdugmtif8; expires=Sun, 19-Feb-2023 11:15:55 GMT; Max-Age=604800; path=/; HttpOnly
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# Strict-Transport-Security: max-age=604800
# Content-Encoding: gzip
#
# 40357 distinct word(s) so far
# Server: nginx
# Date: Sun, 12 Feb 2023 11:15:56 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (5129892c6186f4b40a3a1e6c87794663)
# Set-Cookie: PHPSESSID=celDfEbIWk7L2Oev8W1qWoTLP0vDiUJw; path=/; domain=zavernostnauke.ru; HttpOnly
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate, public
# Pragma: no-cache
# X-Content-Type-Options: nosniff
# X-Frame-Options: SAMEORIGIN
# Content-Encoding: gzip
#
# 40669 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:51 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# Set-Cookie: BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A23; expires=Wed, 07-Feb-2024 11:16:23 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40669 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:15:51 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=bf71pWzvF35OfZa6F4YVNY36THZyY4uX; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:16:24 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A16%3A24; expires=Wed, 07-Feb-2024 11:16:24 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40670 distinct word(s) so far
# 40670 distinct word(s) so far
# 40670 distinct word(s) so far
# File Not Found
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:18:03 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# Set-Cookie: PHPSESSID=tn47ZClqv38RIzAiYRwXsf0l7UclvigD; path=/; domain=minobrnauki.gov.ru; HttpOnly, BITRIX_SM_GUEST_ID=16945330; expires=Wed, 07-Feb-2024 11:18:35 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru, BITRIX_SM_LAST_VISIT=12.02.2023%2014%3A18%3A35; expires=Wed, 07-Feb-2024 11:18:35 GMT; Max-Age=31104000; path=/; domain=minobrnauki.gov.ru
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Cache-Control: no-store, no-cache, must-revalidate
# Pragma: no-cache
# X-Frame-Options: SAMEORIGIN, SAMEORIGIN
# X-Content-Type-Options: nosniff
# Content-Encoding: gzip
#
# 40686 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:18:03 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# P3P: policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"
# X-Powered-CMS: Bitrix Site Manager (8a5fc641d5a15a45d4005bf699c31dee)
# ...
# X-Bitrix-Composite: Cache (200)
# X-Content-Type-Options: nosniff
# X-Frame-Options: SAMEORIGIN
# Referrer-Policy: strict-origin-when-cross-origin
# Strict-Transport-Security: max-age=15768000
# Set-Cookie: SESSID=bbce; path=/; Secure; HttpOnly
# Content-Encoding: gzip
#
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 404 Not Found for https://innopolis.university/proekty/activity/en"
# File Not Found
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# File Not Found
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# File Not Found
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# File Not Found
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# 42021 distinct word(s) so far
# Server: ddos-guard
# Connection: keep-alive
# Keep-Alive: timeout=60
# Set-Cookie: __ddg1_=w68kPMWn2iUUwviALqIr; Domain=.innopolis.university; HttpOnly; Path=/; Expires=Mon, 12-Feb-2024 11:34:30 GMT
# Date: Sun, 12 Feb 2023 11:34:30 GMT
# Content-Type: text/html; charset=UTF-8
# Last-Modified: Thu, 09 Feb 2023 11:05:06 GMT
# ETag: "6c608-5f4425a7fd371-gzip"
# Vary: Accept-Encoding
# Content-Encoding: gzip
# X-Frame-Options: SAMEORIGIN
# X-Host: events.innopolis.university
# cache-control: max-age=0, public
# Transfer-Encoding: chunked
#
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# 42293 distinct word(s) so far
# Server: nginx/1.18.0 (Ubuntu)
# Date: Sun, 12 Feb 2023 11:34:31 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Link: <https://hightech.fm/?p=398721>; rel=shortlink
# Last-Modified: Sun, 12 Feb 2023 11:31:19 GMT
# Pragma: public
# Cache-Control: max-age=3408, public
# ETag: "bccd1d4b3859f653cbccd91ea8ec95e4"
# Content-Encoding: gzip
# Vary: Accept-Encoding
# Strict-Transport-Security: max-age=31536000
#
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# Server: nginx/1.22.0
# Date: Sun, 12 Feb 2023 11:34:33 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: keep-alive
# Vary: HTTPS
# X-Powered-By: PHP/7.4.28
# Expires: Fri, 07 Jun 1974 04:00:00 GMT
# Last-Modified: Sun, 12 Feb 2023 09:54:06 GMT
# X-Bitrix-Composite: Cache (200)
# X-Content-Type-Options: nosniff
# X-Frame-Options: SAMEORIGIN
# Referrer-Policy: strict-origin-when-cross-origin
# Strict-Transport-Security: max-age=15768000
# Set-Cookie: SESSID=bbce; path=/; Secure; HttpOnly
# Content-Encoding: gzip
#
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 404 Not Found for https://innopolis.university/proekty/activity/en"
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# File Not Found
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 403 Forbidden for https://digital.gov.ru/ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# File Not Found
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 404 Not Found for https://innopolis.university/proekty/activity/en"
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 404 Not Found for https://innopolis.university/en/university@innopolis.ru
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 404 Not Found for https://innopolis.university/proekty/activity/en"
# File Not Found
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# 42495 distinct word(s) so far
# https://innopolis.university/en/
# Done
# [(',', 535046), ('.', 344983), ('the', 280665), ('and', 269303), ('of', 243986), ('in', 155985), ('to', 134401), ('university', 124473), ('и', 114043), (')', 111063), ('(', 105503), (':', 93943), ('a', 88950), ('for', 87801), ('в', 81254), ('innopolis', 64647), ('at', 59068), ('i', 54316), ('is', 52857), ('it', 50796)]
